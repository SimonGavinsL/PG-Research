# %%
import pandas as pd

# %%
# Overall results
df = pd.read_csv('src/data/result3.csv')
df
# Out:
#           Key         OriginalName OriginalPrediction  UnequalToName  \
# 0         321  getPushesLowerbound        getPriority              0
# 1         323  setPushesLowerbound     setPageIndexPp              0
# 2         324                 play       loadSettings              2
# 3         343    getInfluenceValue      getColorIndex              0
# 4         351         setPositions       setPositions              0
# ...       ...                  ...                ...            ...
# 23599  460292          setFullName        setFullName              0
# 23600  460294            setPrefix          setPrefix              0
# 23601  460295            getSuffix          getSuffix              0
# 23602  460296       setDateOfBirth     setDateOfBirth              0
# 23603  460298            setSuffix          setSuffix              0
#
#        UnequalToPrediction  Total
# 0                        0      0
# 1                        0      0
# ...

# %%
# Original names and predictions that match
df[df.OriginalName == df.OriginalPrediction]
# Out:
#           Key       OriginalName OriginalPrediction  UnequalToName  \
# 4         351       setPositions       setPositions              0
# 12        376        setInfoText        setInfoText              0
# 19        446  getPlayerPosition  getPlayerPosition              0
# 20        448       setPositions       setPositions              0
# 38        499           getValue           getValue              0
# ...       ...                ...                ...            ...
# 23599  460292        setFullName        setFullName              0
# 23600  460294          setPrefix          setPrefix              0
# 23601  460295          getSuffix          getSuffix              0
# 23602  460296     setDateOfBirth     setDateOfBirth              0
# 23603  460298          setSuffix          setSuffix              0
#
#        UnequalToPrediction  Total
# 4                        0      0
# 12                       0      0
# 19                       0      0
# ...

# %%
# Methods that were genuinely AST-mutated
df[df.Total > 0]
# Out:
#           Key              OriginalName  OriginalPrediction  UnequalToName  \
# 2         324                      play        loadSettings              2
# 14        428      getBestBoardPosition                 NaN              2
# 22        454        setSearchDirection  getSearchDirection              1
# 24        459            getPushesCount      paintComponent              2
# 49        517                   isEqual              equals              2
# ...       ...                       ...                 ...            ...
# 23488  460121                       pop           doRepaint              5
# 23491  460125  verifyAssertionSignature     verifySignature              2
# 23492  460126                      next                next              1
# 23494  460133           getNamespaceURI     getNameSpaceUri              4
# 23495  460134                      dump                dump              2
#
#        UnequalToPrediction  Total
# ...
